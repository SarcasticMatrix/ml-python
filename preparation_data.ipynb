# %%
from models.preparation import import_data, get_dtypes, compute_correlation
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns


data = import_data()
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %%
data.describe()
# Out:
#                age      campaign         pdays      previous  emp.var.rate  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406      2.567593    962.475454      0.172963      0.081886
# std       10.42125      2.770014    186.910907      0.494901      1.570960
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41188.000000   41188.000000  41188.000000  41188.000000
# mean        93.575664     -40.502600      3.621291   5167.035911
# std          0.578840       4.628198      1.734447     72.251528
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %%
data.columns.to_list()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
dtype_to_column = get_dtypes(data)
dtype_to_column
# Out:
# {dtype('int64'): ['age', 'campaign', 'pdays', 'previous'],
#  dtype('float64'): ['emp.var.rate',
#   'cons.price.idx',
#   'cons.conf.idx',
#   'euribor3m',
#   'nr.employed'],
#  dtype('O'): ['job',
#   'marital',
#   'education',
#   'default',
#   'housing',
#   'loan',
#   'contact',
#   'month',
#   'day_of_week',
#   'poutcome',
#   'y']}

# %%
pd.options.mode.use_inf_as_na = True # '' ou numpy.inf considérées comme des NA
np.unique(data.isna())
# Out:
# array([False])

# %% [markdown]
# # Variables numériques

# %%
compute_correlation(data=data)
# Out:
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# emp.var.rate            1.00            0.78           0.20       0.97
# cons.price.idx          0.78            1.00           0.06       0.69
# cons.conf.idx           0.20            0.06           1.00       0.28
# euribor3m               0.97            0.69           0.28       1.00
# nr.employed             0.91            0.52           0.10       0.95
# age                     0.00            0.00           0.13       0.01
# campaign                0.15            0.13           0.01       0.14
# pdays                   0.27            0.08           0.09       0.30
# previous                0.42            0.20           0.05       0.45
#
#                 nr.employed   age  campaign  pdays  previous
# emp.var.rate           0.91  0.00      0.15   0.27      0.42
# cons.price.idx         0.52  0.00      0.13   0.08      0.20
# cons.conf.idx          0.10  0.13      0.01   0.09      0.05
# euribor3m              0.95  0.01      0.14   0.30      0.45
# nr.employed            1.00  0.02      0.14   0.37      0.50
# age                    0.02  1.00      0.00   0.03      0.02
# campaign               0.14  0.00      1.00   0.05      0.08
# pdays                  0.37  0.03      0.05   1.00      0.59
# previous               0.50  0.02      0.08   0.59      1.00

# %% [markdown]
# # Variables catégorielles

# %%
from scipy.stats import chi2_contingency
def cramers_V(var1,var2) :
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))

# %%
labels_categorielles = dtype_to_column[np.dtype('O')]
vars_categorielles = data[labels_categorielles].transpose()

# Test du V de Cramer
rows= []

for var1 in tqdm(vars_categorielles):
  col = []
  for var2 in vars_categorielles :
    cramers = cramers_V(vars_categorielles[var1], vars_categorielles[var2]) # V de Cramer
    col.append(round(cramers,2)) # arrondi du résultat   
  rows.append(col)
  
cramers_results = np.array(rows)
v_cramer_resultats = pd.DataFrame(cramers_results, columns = vars_categorielles.columns, 
                                  index =vars_categorielles.columns)

v_cramer_resultats
# Out:
#   0%|                                                                                                                                                                                 | 0/11 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 col = []
#       9 for var2 in vars_categorielles :
# ---> 10   cramers = cramers_V(vars_categorielles[var1], vars_categorielles[var2]) # V de Cramer
#      11   col.append(round(cramers,2)) # arrondi du résultat
#      12 rows.append(col)
#
# Cell In[7], line 3, in cramers_V(var1, var2)
#       2 def cramers_V(var1,var2) :
# ----> 3   crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
#       4   stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
#       5   obs = np.sum(crosstab) # Number of observations
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:691, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     688     df["__dummy__"] = values
#     689     kwargs = {"aggfunc": aggfunc}
# --> 691 table = df.pivot_table(
#     692     "__dummy__",
#     693     index=unique_rownames,
#     694     columns=unique_colnames,
#     695     margins=margins,
#     696     margins_name=margins_name,
#     697     dropna=dropna,
#     698     **kwargs,
#     699 )
#     701 # Post-process
#     702 if normalize is not False:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:8728, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8711 @Substitution("")
#    8712 @Appender(_shared_docs["pivot_table"])
#    8713 def pivot_table(
#    (...)
#    8724     sort=True,
#    8725 ) -> DataFrame:
#    8726     from pandas.core.reshape.pivot import pivot_table
# -> 8728     return pivot_table(
#    8729         self,
#    8730         values=values,
#    8731         index=index,
#    8732         columns=columns,
#    8733         aggfunc=aggfunc,
#    8734         fill_value=fill_value,
#    8735         margins=margins,
#    8736         dropna=dropna,
#    8737         margins_name=margins_name,
#    8738         observed=observed,
#    8739         sort=sort,
#    8740     )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:180, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     177     agged = grouped.agg(aggfunc)
#     179 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
# --> 180     agged = agged.dropna(how="all")
#     182     # gh-21133
#     183     # we want to down cast if
#     184     # the original values are ints
#     185     # as we grouped with a NaN value
#     186     # and then dropped, coercing to floats
#     187     for v in values:
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:6574, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6571     raise ValueError(f"invalid how option: {how}")
#    6573 if np.all(mask):
# -> 6574     result = self.copy()
#    6575 else:
#    6576     result = self.loc(axis=axis)[mask]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:6368, in NDFrame.copy(self, deep)
#    6258 @final
#    6259 def copy(self: NDFrameT, deep: bool_t | None = True) -> NDFrameT:
#    6260     """
#    6261     Make a copy of this object's indices and data.
#    6262
#    (...)
#    6366     dtype: object
#    6367     """
# -> 6368     data = self._mgr.copy(deep=deep)
#    6369     self._clear_item_cache()
#    6370     return self._constructor(data).__finalize__(self, method="copy")
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py:647, in BaseBlockManager.copy(self, deep)
#     644     def copy_func(ax):
#     645         return ax.copy(deep=True) if deep == "all" else ax.view()
# --> 647     new_axes = [copy_func(ax) for ax in self.axes]
#     648 else:
#     649     new_axes = list(self.axes)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py:647, in <listcomp>(.0)
#     644     def copy_func(ax):
#     645         return ax.copy(deep=True) if deep == "all" else ax.view()
# --> 647     new_axes = [copy_func(ax) for ax in self.axes]
#     648 else:
#     649     new_axes = list(self.axes)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py:645, in BaseBlockManager.copy.<locals>.copy_func(ax)
#     644 def copy_func(ax):
# --> 645     return ax.copy(deep=True) if deep == "all" else ax.view()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:1253, in MultiIndex.view(self, cls)
#    1251 def view(self, cls=None):
#    1252     """this is defined as a copy with the same identity"""
# -> 1253     result = self.copy()
#    1254     result._id = self._id
#    1255     return result
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:1225, in MultiIndex.copy(self, names, dtype, levels, codes, deep, name)
#    1222 levels = levels if levels is not None else self.levels
#    1223 codes = codes if codes is not None else self.codes
# -> 1225 new_index = type(self)(
#    1226     levels=levels,
#    1227     codes=codes,
#    1228     sortorder=self.sortorder,
#    1229     names=names,
#    1230     verify_integrity=False,
#    1231 )
#    1232 new_index._cache = self._cache.copy()
#    1233 new_index._cache.pop("levels", None)  # GH32669
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:329, in MultiIndex.__new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity)
#     327 # we've already validated levels and codes, so shortcut here
#     328 result._set_levels(levels, copy=copy, validate=False)
# --> 329 result._set_codes(codes, copy=copy, validate=False)
#     331 result._names = [None] * len(levels)
#     332 if names is not None:
#     333     # handles name validation
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:1004, in MultiIndex._set_codes(self, codes, level, copy, validate, verify_integrity)
#    1001         raise ValueError("Length of codes must match length of levels.")
#    1003 if level is None:
# -> 1004     new_codes = FrozenList(
#    1005         _coerce_indexer_frozen(level_codes, lev, copy=copy).view()
#    1006         for lev, level_codes in zip(self._levels, codes)
#    1007     )
#    1008 else:
#    1009     level_numbers = [self._get_level_number(lev) for lev in level]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:1005, in <genexpr>(.0)
#    1001         raise ValueError("Length of codes must match length of levels.")
#    1003 if level is None:
#    1004     new_codes = FrozenList(
# -> 1005         _coerce_indexer_frozen(level_codes, lev, copy=copy).view()
#    1006         for lev, level_codes in zip(self._levels, codes)
#    1007     )
#    1008 else:
#    1009     level_numbers = [self._get_level_number(lev) for lev in level]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/multi.py:3953, in _coerce_indexer_frozen(array_like, categories, copy)
#    3951 if copy:
#    3952     array_like = array_like.copy()
# -> 3953 array_like.flags.writeable = False
#    3954 return array_like
#
# KeyboardInterrupt:
